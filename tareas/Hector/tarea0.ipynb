# %% [markdown]
# # Tarea 0

# %% [markdown]
# Capturas de pantalla

# %%
from IPython.core.display import Image 
Image(filename=("/home/solaris/Escritorio/Programación/Jupyter/2017-2_TSFisComputacional-1/tareas/Hector/captura1.jpg"))

# %%
from IPython.core.display import Image 
Image(filename=("/home/solaris/Escritorio/Programación/Jupyter/2017-2_TSFisComputacional-1/tareas/Hector/captura2.jpg"))
